# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
series=pd.read_csv("E:\\notebooks file\\daily-minimum-temperatures.csv",header=0,index_col=0,parse_dates=True)
# Out:
# C:\Users\Server\AppData\Local\Temp\ipykernel_5176\108590816.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   series=pd.read_csv("E:\\notebooks file\\daily-minimum-temperatures.csv",header=0,index_col=0,parse_dates=True)

# %%
series.plot()
plt.show()

# %%
series.hist()
plt.show()

# %%
series.plot(kind='kde')
plt.show()

# %%
from pandas.plotting import lag_plot
lag_plot(series)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(series,lags=30)
plt.show()
